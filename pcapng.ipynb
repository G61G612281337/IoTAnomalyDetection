# %%
# !pip install python-pcapng
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python-pcapng
#   Downloading python_pcapng-2.1.1-py3-none-any.whl (33 kB)
# Installing collected packages: python-pcapng
# Successfully installed python-pcapng-2.1.1

# %%
path_to_attack = '/content/drive/MyDrive/IoT project/anomaly32k (1).pcapng'


from pcapng import FileScanner
import numpy as np

# %%
anomaly_blocks = []
with open(path_to_attack, 'rb') as fp:
    scanner = FileScanner(fp)   
    for block in scanner:
      anomaly_blocks.append(block)

# %%
some_block = anomaly_blocks[10]

# %%
some_block.schema
# Out:
# [('interface_id', IntField(size=32, signed=False), 0),
#  ('timestamp_high', IntField(size=32, signed=False), 0),
#  ('timestamp_low', IntField(size=32, signed=False), 0),
#  ('captured_len', IntField(size=32, signed=False), 0),
#  ('packet_len', IntField(size=32, signed=False), 0),
#  ('packet_data', PacketBytes(), b''),
#  ('options',
#   OptionsField([Option(code=2, name='epb_flags', ftype='epb_flags', multiple=False), Option(code=3, name='epb_hash', ftype='type+bytes', multiple=True), Option(code=4, name='epb_dropcount', ftype='u64', multiple=False), Option(code=5, name='epb_packetid', ftype='u64', multiple=False), Option(code=6, name='epb_queue', ftype='u32', multiple=False), Option(code=7, name='epb_verdict', ftype='type+bytes', multiple=True)]),
#   None)]

# %%
some_block._decode('packet_data')
